# %%
# %matplotlib inline
##importing programs from pyzotero, matplotlib, collections
import matplotlib.pyplot as plt
from pyzotero import zotero
from collections import Counter

##defining variables
library_id = "655084"
library_type = "group"
api_key= "ajdUMPwUpwULGD2cwdXaOASG"

##
zot = zotero.Zotero(library_id, library_type, api_key)
hybrid_blended = zot.everything(zot.collection_items("95HW46ZG"))
dates = [int(i["data"]["date"]) for i in hybrid_blended]


years = [d for d in set(dates)]
years.sort()
counts = Counter([u for u in dates])
articles = [counts[y] for y in years]
print (years)
print (articles)
plt.figure(figsize=(20,10))
plt.plot(years, articles)
plt.show()
# Out:
# [1938, 1952, 1990, 1995, 1999, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016]
# [1, 1, 1, 1, 1, 2, 5, 3, 7, 11, 21, 22, 29, 31, 42, 34, 48, 22, 26, 30, 19]
